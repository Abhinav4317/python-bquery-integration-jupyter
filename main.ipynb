# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
from bq_module.manager import BigQueryManager

KEY_FILE = os.path.join("bq_module", "config", "service_key.json")


try:
    bq = BigQueryManager(key_path=KEY_FILE)
    print("BigQuery Manager Initialized Successfully!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# Connected to BigQuery Project: bachatt-bigquery-project
# BigQuery Manager Initialized Successfully!
# /Users/abhinav.gangwarbachatt.app/Documents/bachatt-pipelines/python-bq-integration-jupyter/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...

# %%
params = {
    "user_name": "JupyterUser",
    "limit_val": 10
}

df = bq.run_defined_query("test_connection", params=params, save_csv=False)

display(df)
# Out:
# ⏳ Running query... (Export CSV: False)
# /Users/abhinav.gangwarbachatt.app/Documents/bachatt-pipelines/python-bq-integration-jupyter/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Query finished. Rows returned: 1
#                   status                      server_time   checked_by
# 0  Connection Successful 2025-11-25 05:50:48.051795+00:00  JupyterUser

# %%
raw_sql = """
    SELECT *
        FROM `bachatt-bigquery-project.prod_db.investmentdb_transactions`
        WHERE date(updated_at) >= '2025-11-23' AND date(updated_at) <= '2025-11-25'
        LIMIT 5
"""

df_raw = bq.run_raw_query(
    raw_sql, 
    params=None, 
    save_csv=True,
    filename="investmentdb_transactions"
)

if not df_raw.empty:
    print(f"Found {len(df_raw)} records for investmentdb_transactions:")
    print(df_raw)
# Out:
# ⏳ Running query... (Export CSV: True)
# /Users/abhinav.gangwarbachatt.app/Documents/bachatt-pipelines/python-bq-integration-jupyter/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Query finished. Rows returned: 5
# Data saved to: data/exports/investmentdb_transactions_20251125_104716.csv
# Found 5 records for investmentdb_transactions:
#                         _airbyte_raw_id            _airbyte_extracted_at  \
# 0  938c315d-19ad-4026-9f2d-19ecc02b8118 2025-11-24 22:55:12.957000+00:00
# 1  222cad99-2176-43af-8cfc-2c54f176cf1e 2025-11-24 22:55:12.957000+00:00
# 2  482647f4-4f75-4879-811e-642c2340c590 2025-11-24 22:55:12.957000+00:00
# 3  9a8fbe2d-3fb5-46ec-b8c0-3b2af3ec0604 2025-11-24 22:55:12.957000+00:00
# 4  4d2061b2-5808-4d47-874d-4370a5130dea 2025-11-24 22:55:12.957000+00:00
#
# ...

# %%
df_raw_2 = bq.run_defined_query(
    "sample_schedules_query",
    params=None, 
    save_csv=True
)

if not df_raw_2.empty:
    print(f"Found {len(df_raw_2)} records for investmentdb_schedules:")
    print(df_raw_2)
# Out:
# ⏳ Running query... (Export CSV: True)
# /Users/abhinav.gangwarbachatt.app/Documents/bachatt-pipelines/python-bq-integration-jupyter/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Query finished. Rows returned: 5
# Data saved to: data/exports/sample_schedules_query_20251125_105842.csv
# Found 5 records for investmentdb_schedules:
#                         _airbyte_raw_id            _airbyte_extracted_at  \
# 0  4eb16444-03bc-44b6-ab4d-1fd9a19297cf 2025-11-25 04:55:13.077000+00:00
# 1  11f17843-25f2-4efb-8f29-2a892fdb300a 2025-11-25 04:55:13.077000+00:00
# 2  ed7455f9-a828-4dda-8d97-98af94b6c74f 2025-11-25 04:55:13.077000+00:00
# 3  31b65d4a-c8e5-4182-b477-b7cab7255006 2025-11-25 04:55:13.077000+00:00
# 4  8e66b534-780a-4360-88ff-efd84c3635f5 2025-11-25 04:55:13.077000+00:00
#
# ...
